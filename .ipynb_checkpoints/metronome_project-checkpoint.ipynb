# %%
import numpy as np 
import pandas as pd
from urllib import request
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = "./data/Code data_METRONOM.csv"
df = pd.read_csv(filepath, encoding = "ISO-8859-1", error_bad_lines=False, sep="\t")

df.tail()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         store_id          store_desc  CATMAN_BUY_DOMAIN_ID  \
# 738666       579  LIEFERDEPOT BERLIN                    66
# 738667       579  LIEFERDEPOT BERLIN                    66
# 738668       579  LIEFERDEPOT BERLIN                    66
# 738669       579  LIEFERDEPOT BERLIN                    66
# 738670       579  LIEFERDEPOT BERLIN                    66
#
#        CATMAN_BUY_DOMAIN_DESC  PCG_MAIN_CAT_ID  PCG_CAT_ID  PCG_CAT_DESC  \
# 738666             ACM BLUMEN              994          99  Sammelnummer
# 738667             ACM BLUMEN              994          99  Sammelnummer
# 738668             ACM BLUMEN              994          99  Sammelnummer
# 738669             ACM BLUMEN              994          99  Sammelnummer
# ...

# %%
df.sort_values(by=['Bv Stk'])
# Out:
#         store_id          store_desc  CATMAN_BUY_DOMAIN_ID  \
# 165046       579  LIEFERDEPOT BERLIN                    52
# 165052       579  LIEFERDEPOT BERLIN                    52
# 165083       579  LIEFERDEPOT BERLIN                    52
# 165125       579  LIEFERDEPOT BERLIN                    52
# 165128       579  LIEFERDEPOT BERLIN                    52
# ...          ...                 ...                   ...
# 738666       579  LIEFERDEPOT BERLIN                    66
# 738667       579  LIEFERDEPOT BERLIN                    66
# 738668       579  LIEFERDEPOT BERLIN                    66
# 738669       579  LIEFERDEPOT BERLIN                    66
# 738670       579  LIEFERDEPOT BERLIN                    66
#
#        CATMAN_BUY_DOMAIN_DESC  PCG_MAIN_CAT_ID  PCG_CAT_ID  PCG_CAT_DESC  \
# 165046   ACM MOLKEREIPRODUKTE              933          10          Eier
# 165052   ACM MOLKEREIPRODUKTE              933          10          Eier
# ...

# %%
df.rename(columns={"CATMAN_BUY_DOMAIN_ID": "Purchasing Area ID", 
                   "CATMAN_BUY_DOMAIN_DESC" : "Purchasing Area Description", 
                   "PCG_MAIN_CAT_ID" : "Main Product Group ID",
                   "PCG_CAT_ID" : "Product Group Category ID",
                   "PCG_CAT_DESC" : "Product Group Category Description",
                   "PCG_SUB_CAT_ID" : "Product subgroup Category ID",
                   "PCG_SUB_CAT_DESC" : "Product subgroup Category Description",
                   "Bv NNEK" : "Monthly Shrinkage in euros",
                   "Bv Stk" : "Monthly Shrinkage in pieces",
                   "WA Stück" : "Sales in Pieces",
                   "Umsatz VK Netto" : "Sales in euros"
                   
                  })
# Out:
#         store_id          store_desc  Purchasing Area ID  \
# 0            579  LIEFERDEPOT BERLIN                  52
# 1            579  LIEFERDEPOT BERLIN                  52
# 2            579  LIEFERDEPOT BERLIN                  52
# 3            579  LIEFERDEPOT BERLIN                  52
# 4            579  LIEFERDEPOT BERLIN                  52
# ...          ...                 ...                 ...
# 738666       579  LIEFERDEPOT BERLIN                  66
# 738667       579  LIEFERDEPOT BERLIN                  66
# 738668       579  LIEFERDEPOT BERLIN                  66
# 738669       579  LIEFERDEPOT BERLIN                  66
# 738670       579  LIEFERDEPOT BERLIN                  66
#
#        Purchasing Area Description  Main Product Group ID  \
# 0             ACM MOLKEREIPRODUKTE                    803
# 1             ACM MOLKEREIPRODUKTE                    803
# 2             ACM MOLKEREIPRODUKTE                    803
# ...

# %%
df_rename = df.rename(columns={“CATMAN_BUY_DOMAIN_ID” : “Purchasing Area ID”,“CATMAN_BUY_DOMAIN_DESC”: “Purchasing Area Description”,
                   “PCG_MAIN_CAT_ID”: “Main Product Group ID”,“PCG_CAT_ID”: “Product Group Category ID”,
                  “PCG_CAT_DESC”: “Product Group Category Description”,“PCG_SUB_CAT_ID”: “Product subgroup Category ID”,
                  “PCG_SUB_CAT_DESC”:“Product subgroup Category Description”,“Bv NNEK”: “Monthly Shrinkage in euros”,
                   “Bv Stk”:“Monthly Shrinkage in pieces”,“WA Stück”:“Sales in Pieces”,“c”:“Sales in euros”})
# Out:
#   File "<ipython-input-29-215761fe18f6>", line 1
#     df_rename = df.rename(columns={“CATMAN_BUY_DOMAIN_ID” : “Purchasing Area ID”,“CATMAN_BUY_DOMAIN_DESC”: “Purchasing Area Description”,
#                                                         ^
# SyntaxError: invalid character in identifier
